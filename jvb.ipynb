# %%
# Import the function from the Python file
from jvb import read_log_file

# Define the path to the log file
log_file_path = 'jvb.log'

# Call the function to get the DataFrame
df = read_log_file(log_file_path)

# Display the DataFrame
(df.sample(20))
# Out:
#                   Timestamp  \
# 49  2024-04-22 22:01:40.183
# 31  2024-04-22 22:01:36.603
# 1   2024-04-22 21:59:05.277
# 4   2024-04-22 21:59:05.336
# 15  2024-04-22 21:59:07.932
# 34  2024-04-22 22:01:38.230
# 30  2024-04-22 22:01:36.579
# 46  2024-04-22 22:01:39.271
# 9   2024-04-22 21:59:07.428
# 25  2024-04-22 21:59:09.117
# 44  2024-04-22 22:01:39.079
# 8   2024-04-22 21:59:07.136
# 48  2024-04-22 22:01:40.182
# 5   2024-04-22 21:59:06.159
# 40  2024-04-22 22:01:38.657
# 45  2024-04-22 22:01:39.080
# 51  2024-04-22 22:01:41.261
# 42  2024-04-22 22:01:38.980
# 47  2024-04-22 22:01:39.999
# 17  2024-04-22 21:59:07.970
#
#                                        Thread Context Log Level  \
# 49  org.glassfish.jersey.internal.inject.Providers...   WARNING
# 31                                     MainKt.main#75      INFO
# 1   ReadOnlyConfigurationService.reloadConfigurati...      INFO
# 4                                      MainKt.main#75      INFO
# 15  org.eclipse.jetty.server.handler.ContextHandle...      INFO
# 34                              TaskPools.<clinit>#87      INFO
# 30           JitsiConfig$Companion.reloadNewConfig#94      INFO
# 46            org.eclipse.jetty.server.Server.doStart      INFO
# 9                        UlimitCheck.printUlimits#109      INFO
# 25  org.eclipse.jetty.server.AbstractConnector.doS...      INFO
# 44            org.eclipse.jetty.server.Server.doStart      INFO
# 8                             HealthChecker.start#122      INFO
# 48  org.glassfish.jersey.internal.inject.Providers...   WARNING
# 5    org.ice4j.ice.harvest.AbstractUdpListener.<init>      INFO
# 40         ColibriWebSocketService.registerServlet#84      INFO
# 45                                    MainKt.main#134      INFO
# 51  org.eclipse.jetty.server.handler.ContextHandle...      INFO
# 42  org.eclipse.jetty.server.handler.ContextHandle...      INFO
# 47  org.glassfish.jersey.server.wadl.WadlFeature.c...   WARNING
# 17            org.eclipse.jetty.server.Server.doStart      INFO
#
#                                               Message
# 49  A provider org.jitsi.rest.Version registered i...
# 31  Starting jitsi-videobridge version 2.3.92-g64f...
# 1   loading config file at path /etc/jitsi/videobr...
# 4   Starting jitsi-videobridge version 2.3.92-g64f...
# 15  Started o.e.j.s.ServletContextHandler@47e4d9d0...
# 34  TaskPools detected 7 processors, creating the ...
# 30  Reloading the Typesafe config source (previous...
# 46  jetty-11.0.14; built: 2023-02-22T23:41:48.575Z...
# 9   Running with open files limit 65000 (hard 6500...
# 25  Started ServerConnector@4682eba5{HTTP/1.1, (ht...
# 44  Started Server@1bbae752{STARTING}[11.0.14,sto=...
# 8   Started with interval=60000, timeout=PT1M30S, ...
# 48  A provider org.jitsi.rest.Health registered in...
# 5   Initialized AbstractUdpListener with address 1...
# 40  Registering servlet with baseUrls = [wss://127...
# 45                       Starting private http server
# 51  Started o.e.j.s.ServletContextHandler@750f64fe...
# 42  Started o.e.j.s.ServletContextHandler@29a4f594...
# 47  JAXBContext implementation could not be found....
# 17  Started Server@4c9e38{STARTING}[11.0.14,sto=0]...
