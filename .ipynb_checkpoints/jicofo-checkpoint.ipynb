# %%
from jicofo import analyze_jicofo_log 

# Path to the jicofo.log file
jicofo_log_file = 'jicofo.log'

# Call the function to analyze the log file and get the DataFrame
jicofo_df = analyze_jicofo_log(jicofo_log_file)
jicofo_df.sample(10)
# Out:
#    service               timestamp log_level thread  \
# 58  Jicofo 2024-04-22 22:13:53.365      INFO     32
# 35  Jicofo 2024-04-22 22:01:48.155   WARNING      1
# 17  Jicofo 2024-04-22 22:01:45.222      INFO      1
# 18  Jicofo 2024-04-22 22:01:45.369      INFO      1
# 20  Jicofo 2024-04-22 22:01:46.723      INFO     13
# 34  Jicofo 2024-04-22 22:01:48.154   WARNING      1
# 33  Jicofo 2024-04-22 22:01:47.955   WARNING      1
# 49  Jicofo 2024-04-22 22:11:49.658      INFO     19
# 47  Jicofo 2024-04-22 22:11:49.650      INFO     19
# 26  Jicofo 2024-04-22 22:01:47.011      INFO     31
#
#                                               message
# 58  [room=74845b10-5b53-4c64-9e42-24d43f6e756e@bre...
# 35  org.glassfish.jersey.internal.inject.Providers...
# 17  JicofoServices.<init>#117: No SIP Jibri detect...
# 18  JicofoServices.<init>#146: Starting HTTP serve...
# 20  [xmpp_connection=client] XmppProvider.doConnec...
# 34  org.glassfish.jersey.internal.inject.Providers...
# 33  org.glassfish.jersey.server.wadl.WadlFeature.c...
# 49  [room=dependenttsunamisfleepretty@conference.1...
# 47  [room=dependenttsunamisfleepretty@conference.1...
# 26  ConferenceIqHandler.componentsChanged#211: Usi...
